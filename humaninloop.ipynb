# %%
from predict_superclass import human_in_loop

# %%
imgfolder = "birdpics/White-throated Kingfisher"
human_in_loop(imgfolder)
